# %%
# TODO drop Kherson point
# TODO investigate Unnamed

# %%
import pandas as pd
import seaborn as sns

# %%
SEED = 14

# %%
initial_hotspots = pd.read_csv("data_source/hotspots.csv")
print(initial_hotspots.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401 entries, 0 to 1400
# Data columns (total 47 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1401 non-null   int64
#  1   id                    1401 non-null   int64
#  2   foursquare_id         607 non-null    object
#  3   name                  923 non-null    object
#  4   address               1219 non-null   object
#  5   lat                   1401 non-null   float64
#  6   lng                   1401 non-null   float64
#  7   category              1267 non-null   object
#  8   source                1221 non-null   object
#  9   ssid                  1328 non-null   object
#  10  bssid                 1330 non-null   object
#  11  mac                   0 non-null      float64
#  12  altitude              1190 non-null   float64
#  13  deleted_at            479 non-null    object
#  14  created_at            1401 non-null   object
#  15  updated_at            1401 non-null   object
#  16  source_id             14 non-null     float64
#  17  zone_id               1401 non-null   float64
#  18  owner_id              699 non-null    float64
#  19  author_device_id      1207 non-null   object
#  20  deleted_by            479 non-null    float64
#  21  client_ip             1065 non-null   object
#  22  google_place_id       192 non-null    object
#  23  zip_code              0 non-null      float64
#  24  timezone              0 non-null      float64
#  25  city_name             1401 non-null   object
#  26  country_code          1401 non-null   object
#  27  address_en            293 non-null    object
#  28  last_connected_at     700 non-null    object
#  29  download_speed        299 non-null    float64
#  30  upload_speed          299 non-null    float64
#  31  ping_time             295 non-null    float64
#  32  last_seen_at          982 non-null    object
#  33  captive_portal_mode   858 non-null    float64
#  34  connections_count     1114 non-null   float64
#  35  baidu_place_id        0 non-null      float64
#  36  uuid                  1401 non-null   object
#  37  service_info          1049 non-null   object
#  38  region_id             1328 non-null   float64
#  39  published_to_website  213 non-null    object
#  40  lonlat                1401 non-null   object
#  41  installation_id       186 non-null    float64
#  42  state_code            0 non-null      float64
#  43  place_id              0 non-null      float64
#  44  deletion_reason       0 non-null      float64
#  45  score_v3              1390 non-null   float64
#  46  score_v4              926 non-null    float64
# dtypes: float64(23), int64(2), object(22)
# memory usage: 514.6+ KB
# None

# %% [markdown]
# ## Drop NA columns and rows and const columns

# %%
hotspots = initial_hotspots.dropna(how="all", axis = 1).dropna(how="all", axis = 0)
print([x for x in initial_hotspots.columns if x not in hotspots.columns])
print()
hotspots_nunique = hotspots.nunique(dropna = False)
const_columns = hotspots_nunique[hotspots_nunique == 1].index
print(hotspots_nunique[hotspots_nunique == 1])
print()
hotspots.drop(columns = const_columns, inplace = True)
hotspots.drop(columns = ["Unnamed: 0"], inplace = True)


print(hotspots.info())
# Out:
# ['mac', 'zip_code', 'timezone', 'baidu_place_id', 'state_code', 'place_id', 'deletion_reason']
#
# city_name       1
# country_code    1
# dtype: int64
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401 entries, 0 to 1400
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1401 non-null   int64
#  1   foursquare_id         607 non-null    object
#  2   name                  923 non-null    object
#  3   address               1219 non-null   object
#  4   lat                   1401 non-null   float64
#  5   lng                   1401 non-null   float64
#  6   category              1267 non-null   object
#  7   source                1221 non-null   object
#  8   ssid                  1328 non-null   object
#  9   bssid                 1330 non-null   object
#  10  altitude              1190 non-null   float64
#  11  deleted_at            479 non-null    object
#  12  created_at            1401 non-null   object
#  13  updated_at            1401 non-null   object
#  14  source_id             14 non-null     float64
#  15  zone_id               1401 non-null   float64
#  16  owner_id              699 non-null    float64
#  17  author_device_id      1207 non-null   object
#  18  deleted_by            479 non-null    float64
#  19  client_ip             1065 non-null   object
#  20  google_place_id       192 non-null    object
#  21  address_en            293 non-null    object
#  22  last_connected_at     700 non-null    object
#  23  download_speed        299 non-null    float64
#  24  upload_speed          299 non-null    float64
#  25  ping_time             295 non-null    float64
#  26  last_seen_at          982 non-null    object
#  27  captive_portal_mode   858 non-null    float64
#  28  connections_count     1114 non-null   float64
#  29  uuid                  1401 non-null   object
#  30  service_info          1049 non-null   object
#  31  region_id             1328 non-null   float64
#  32  published_to_website  213 non-null    object
#  33  lonlat                1401 non-null   object
#  34  installation_id       186 non-null    float64
#  35  score_v3              1390 non-null   float64
#  36  score_v4              926 non-null    float64
# dtypes: float64(16), int64(1), object(20)
# memory usage: 405.1+ KB
# None

# %%
hotspots.dropna(how = "any", axis = 0)
# Out:
# Empty DataFrame
# Columns: [id, foursquare_id, name, address, lat, lng, category, source, ssid, bssid, altitude, deleted_at, created_at, updated_at, source_id, zone_id, owner_id, author_device_id, deleted_by, client_ip, google_place_id, address_en, last_connected_at, download_speed, upload_speed, ping_time, last_seen_at, captive_portal_mode, connections_count, uuid, service_info, region_id, published_to_website, lonlat, installation_id, score_v3, score_v4]
# Index: []

# %% [markdown]
# ## Map

# %%
from typing import List, Tuple
import folium
from geopy.geocoders import Nominatim
import pandas as pd


def get_coordinates(city: str) -> Tuple[float, float]:
    """Gets the latitude and longitude of a city using geocoding."""
    geolocator = Nominatim(user_agent="my-custom-application")
    location = geolocator.geocode(city)
    return location.latitude, location.longitude

def add_marker(row: pd.Series) -> None:
    """Adds a marker to a folium map for a given row in a DataFrame."""
    popup_html = f"<b>name: {row['name']}</b>"
    display_columns = ["id", "address", "connections_count", "score_v3", "score_v4"]
    for column in display_columns:
        popup_html += f"<br>{column}: {row[column]}"
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=popup_html
    ).add_to(cherkasy_map)

# Define Cherkasy's coordinates
latitude, longitude = get_coordinates("Ukraine")

# Create a folium map centered on Cherkasy City
cherkasy_map = folium.Map(location=[latitude, longitude], zoom_start=7)

# Apply the add_marker function to each row of the DataFrame using the apply method
hotspots.apply(add_marker, axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 1396    None
# 1397    None
# 1398    None
# 1399    None
# 1400    None
# Length: 1401, dtype: object

# %%
cherkasy_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b886ab90a55cc57ffb171124d5778e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b886ab90a55cc57ffb171124d5778e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b886ab90a55cc57ffb171124d5778e3 = L.map(
#                 &quot;map_0b886ab90a55cc57ffb171124d5778e3&quot;,
#                 {
#                     center: [49.4871968, 31.2718321],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4019f15d8374d76a814f99f341ba9d67 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b886ab90a55cc57ffb171124d5778e3);
#
#
#             var marker_f4cc905448cdaffb56f3e82d0aa7f3b1 = L.marker(
#                 [49.448038, 32.064749],
#                 {}
#             ).addTo(map_0b886ab90a55cc57ffb171124d5778e3);
#
#
#         var popup_07fb42eaad4d4443e06b866386a004f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ba79dab593bbe20f7de9110e9514a1f = $(`&lt;div id=&quot;html_3ba79dab593bbe20f7de9110e9514a1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;name: Сквер ім. Богдана Хмельницького&lt;/b&gt;&lt;br&gt;id: 819789&lt;br&gt;address: Замковий узвіз&lt;br&gt;connections_count: nan&lt;br&gt;score_v3: 0.04&lt;br&gt;score_v4: nan&lt;/div&gt;`)[0];
#                 popup_07fb42eaad4d4443e06b866386a004f9.setContent(html_3ba79dab593bbe20f7de9110e9514a1f);
#
#
#
#         marker_f4cc905448cdaffb56f3e82d0aa7f3b1.bindPopup(popup_07fb42eaad4d4443e06b866386a004f9)
#         ;
#
#
#
#
#             var marker_56ab28cd2e496f790a8267486db48781 = L.marker(
#                 [49.442546, 32.062713],
#                 {}
#             ).addTo(map_0b886ab90a55cc57ffb171124d5778e3);
#
#
#         var popup_dfa6825d5755530a989ee7f7b851b809 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_363608b40ecf152432d6c20ad47545c7 = $(`&lt;div id=&quot;html_363608b40ecf152432d6c20ad47545c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;name: Сладкарница&lt;/b&gt;&lt;br&gt;id: 68053&lt;br&gt;address: бул. Шевченка, 197&lt;br&gt;connections_count: nan&lt;br&gt;score_v3: 0.04&lt;br&gt;score_v4: nan&lt;/div&gt;`)[0];
#                 popup_dfa6825d5755530a989ee7f7b851b809.setContent(html_363608b40ecf152432d6c20ad47545c7);
#
#
#
#         marker_56ab28cd2e496f790a8267486db48781.bindPopup(popup_dfa6825d5755530a989ee7f7b851b809)
#         ;
#
#
#
#
#             var marker_e72813cef017692ccc2ec8c229250977 = L.marker(
#                 [49.440851, 32.06453],
#                 {}
#             ).addTo(map_0b886ab90a55cc57ffb171124d5778e3);
#
#
#         var popup_b4ff6e6ad1ff7257f73265ebd9aa4d90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eade0bff1f9c89f841d7c8f1754cfece = $(`&lt;div id=&quot;html_eade0bff1f9c89f841d7c8f1754cfece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;name: McDonald&#x27;s&lt;/b&gt;&lt;br&gt;id: 68055&lt;br&gt;address: вул. Смілянська, 31&lt;br&gt;connections_count: nan&lt;br&gt;score_v3: 0.0&lt;br&gt;score_v4: nan&lt;/div&gt;`)[0];
#                 popup_b4ff6e6ad1ff7257f73265ebd9aa4d90.setContent(html_eade0bff1f9c89f841d7c8f1754cfece);
#
#
#
#         marker_e72813cef017692ccc2ec8c229250977.bindPopup(popup_b4ff6e6ad1ff7257f73265ebd9aa4d90)
#         ;
#
#
#
#
#             var marker_7aef226e3ee5e3edfc99d0a7f7f6e26a = L.marker(
#                 [49.427863, 32.092609],
#                 {}
#             ).addTo(map_0b886ab90a55cc57ffb171124d5778e3);
#
#
#         var popup_6944edc677f3791c70f64fe542ed6b19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ddc02aa88b89f72edcc40919677150f = $(`&lt;div id=&quot;html_1ddc02aa88b89f72edcc40919677150f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;name: Неаполь&lt;/b&gt;&lt;br&gt;id: 68051&lt;br&gt;address: вул. Різдв&#x27;яна 50&lt;br&gt;connections_count: nan&lt;br&gt;score_v3: 0.01&lt;br&gt;score_v4: nan&lt;/div&gt;`)[0];
#                 popup_6944edc677f3791c70f64fe542ed6b19.setContent(html_1ddc02aa88b89f72edcc40919677150f);
#
#
#
#         marker_7aef226e3ee5e3edfc99d0a7f7f6e26a.bindPopup(popup_6944edc677f3791c70f64fe542ed6b19)
#         ;
#
#
#
#
#             var marker_37582b0da6e3717f059c5bcf2e9fb838 = L.marker(
#                 [49.434087, 32.090953],
#                 {}
#             ).addTo(map_0b886ab90a55cc57ffb171124d5778e3);
#
#
#         var popup_f22aaf6724697de1c2cd066a18405754 = L.popup({&

# %%
kherson_point_id = 735258
hotspots = hotspots[hotspots.id != kherson_point_id]

# %%
from typing import List, Tuple
import folium
from geopy.geocoders import Nominatim
import pandas as pd


def get_coordinates(city: str) -> Tuple[float, float]:
    """Gets the latitude and longitude of a city using geocoding."""
    geolocator = Nominatim(user_agent="my-custom-application")
    location = geolocator.geocode(city)
    return location.latitude, location.longitude

def add_marker(row: pd.Series) -> None:
    """Adds a marker to a folium map for a given row in a DataFrame."""
    popup_html = f"<b>name: {row['name']}</b>"
    display_columns = ["id", "address", "connections_count", "score_v3", "score_v4"]
    for column in display_columns:
        popup_html += f"<br>{column}: {row[column]}"
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=popup_html
    ).add_to(cherkasy_map)

# Define Cherkasy's coordinates
latitude, longitude = get_coordinates("Ukraine")

# Create a folium map centered on Cherkasy City
cherkasy_map = folium.Map(location=[latitude, longitude], zoom_start=7)

# Apply the add_marker function to each row of the DataFrame using the apply method
hotspots.apply(add_marker, axis=1)

cherkasy_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8630098c2502c3faf35efd1a6bb2d51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8630098c2502c3faf35efd1a6bb2d51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8630098c2502c3faf35efd1a6bb2d51 = L.map(
#                 &quot;map_d8630098c2502c3faf35efd1a6bb2d51&quot;,
#                 {
#                     center: [49.4871968, 31.2718321],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d59f80f77fab87332c515e360d2d78bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8630098c2502c3faf35efd1a6bb2d51);
#
#
#             var marker_03b2939de200eb89a4127259515aa649 = L.marker(
#                 [49.448038, 32.064749],
#                 {}
#             ).addTo(map_d8630098c2502c3faf35efd1a6bb2d51);
#
#
#         var popup_08344cb5dabcd66cc74c5b452a51eb86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba499091e3331fba15673182ae8c9e40 = $(`&lt;div id=&quot;html_ba499091e3331fba15673182ae8c9e40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;name: Сквер ім. Богдана Хмельницького&lt;/b&gt;&lt;br&gt;id: 819789&lt;br&gt;address: Замковий узвіз&lt;br&gt;connections_count: nan&lt;br&gt;score_v3: 0.04&lt;br&gt;score_v4: nan&lt;/div&gt;`)[0];
#                 popup_08344cb5dabcd66cc74c5b452a51eb86.setContent(html_ba499091e3331fba15673182ae8c9e40);
#
#
#
#         marker_03b2939de200eb89a4127259515aa649.bindPopup(popup_08344cb5dabcd66cc74c5b452a51eb86)
#         ;
#
#
#
#
#             var marker_839a48c209ec5de67f32632ccf0d8377 = L.marker(
#                 [49.442546, 32.062713],
#                 {}
#             ).addTo(map_d8630098c2502c3faf35efd1a6bb2d51);
#
#
#         var popup_f66c0260ae9d70fd0182255b4636ae51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_831ca5c56854a5bf70ff92bc5be61a18 = $(`&lt;div id=&quot;html_831ca5c56854a5bf70ff92bc5be61a18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;name: Сладкарница&lt;/b&gt;&lt;br&gt;id: 68053&lt;br&gt;address: бул. Шевченка, 197&lt;br&gt;connections_count: nan&lt;br&gt;score_v3: 0.04&lt;br&gt;score_v4: nan&lt;/div&gt;`)[0];
#                 popup_f66c0260ae9d70fd0182255b4636ae51.setContent(html_831ca5c56854a5bf70ff92bc5be61a18);
#
#
#
#         marker_839a48c209ec5de67f32632ccf0d8377.bindPopup(popup_f66c0260ae9d70fd0182255b4636ae51)
#         ;
#
#
#
#
#             var marker_1d1287f213b215ce4b8aa7d06798e134 = L.marker(
#                 [49.440851, 32.06453],
#                 {}
#             ).addTo(map_d8630098c2502c3faf35efd1a6bb2d51);
#
#
#         var popup_3681f863b132d09c1cc6107bdea1a4ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7df6ae334788e1d8601a61a80e4374f7 = $(`&lt;div id=&quot;html_7df6ae334788e1d8601a61a80e4374f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;name: McDonald&#x27;s&lt;/b&gt;&lt;br&gt;id: 68055&lt;br&gt;address: вул. Смілянська, 31&lt;br&gt;connections_count: nan&lt;br&gt;score_v3: 0.0&lt;br&gt;score_v4: nan&lt;/div&gt;`)[0];
#                 popup_3681f863b132d09c1cc6107bdea1a4ee.setContent(html_7df6ae334788e1d8601a61a80e4374f7);
#
#
#
#         marker_1d1287f213b215ce4b8aa7d06798e134.bindPopup(popup_3681f863b132d09c1cc6107bdea1a4ee)
#         ;
#
#
#
#
#             var marker_34323a694a0ee0f5662fe4c72a7b9580 = L.marker(
#                 [49.427863, 32.092609],
#                 {}
#             ).addTo(map_d8630098c2502c3faf35efd1a6bb2d51);
#
#
#         var popup_d2b1bf634243c401d116b48ec8c9139e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a0ae2e1e2d622174c1bdc1431e734c3 = $(`&lt;div id=&quot;html_9a0ae2e1e2d622174c1bdc1431e734c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;name: Неаполь&lt;/b&gt;&lt;br&gt;id: 68051&lt;br&gt;address: вул. Різдв&#x27;яна 50&lt;br&gt;connections_count: nan&lt;br&gt;score_v3: 0.01&lt;br&gt;score_v4: nan&lt;/div&gt;`)[0];
#                 popup_d2b1bf634243c401d116b48ec8c9139e.setContent(html_9a0ae2e1e2d622174c1bdc1431e734c3);
#
#
#
#         marker_34323a694a0ee0f5662fe4c72a7b9580.bindPopup(popup_d2b1bf634243c401d116b48ec8c9139e)
#         ;
#
#
#
#
#             var marker_78a11ba173def2a3c5634e5d8b23e34b = L.marker(
#                 [49.434087, 32.090953],
#                 {}
#             ).addTo(map_d8630098c2502c3faf35efd1a6bb2d51);
#
#
#         var popup_c4eedae107c9d4e3764c55815ae9e32b = L.popup({&

# %% [markdown]
# ## Cast Types

# %%
hotspots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1400 entries, 0 to 1400
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1400 non-null   int64
#  1   foursquare_id         606 non-null    object
#  2   name                  922 non-null    object
#  3   address               1218 non-null   object
#  4   lat                   1400 non-null   float64
#  5   lng                   1400 non-null   float64
#  6   category              1266 non-null   object
#  7   source                1221 non-null   object
#  8   ssid                  1327 non-null   object
#  9   bssid                 1329 non-null   object
#  10  altitude              1190 non-null   float64
#  11  deleted_at            479 non-null    object
#  12  created_at            1400 non-null   object
#  13  updated_at            1400 non-null   object
#  14  source_id             14 non-null     float64
#  15  zone_id               1400 non-null   float64
#  16  owner_id              699 non-null    float64
#  17  author_device_id      1207 non-null   object
#  18  deleted_by            479 non-null    float64
#  19  client_ip             1065 non-null   object
#  20  google_place_id       192 non-null    object
#  21  address_en            293 non-null    object
#  22  last_connected_at     699 non-null    object
#  23  download_speed        298 non-null    float64
#  24  upload_speed          298 non-null    float64
#  25  ping_time             294 non-null    float64
#  26  last_seen_at          981 non-null    object
#  27  captive_portal_mode   857 non-null    float64
#  28  connections_count     1113 non-null   float64
#  29  uuid                  1400 non-null   object
#  30  service_info          1048 non-null   object
#  31  region_id             1327 non-null   float64
#  32  published_to_website  213 non-null    object
#  33  lonlat                1400 non-null   object
#  34  installation_id       186 non-null    float64
#  35  score_v3              1389 non-null   float64
#  36  score_v4              925 non-null    float64
# dtypes: float64(16), int64(1), object(20)
# memory usage: 415.6+ KB

# %%
hotspots.select_dtypes(include='object')
# Out:
#                  foursquare_id                             name  \
# 0     4e85e8539a523c0720879495  Сквер ім. Богдана Хмельницького
# 1     4eb5300f93ad2365700a52f0                      Сладкарница
# 2     4c4f043392b6a5938661e270                       McDonald's
# 3     4e5fa5cc2271a996808ff24c                          Неаполь
# 4     4e873d5e0aafa209e6026035                  Сушия / Sushiya
# ...                        ...                              ...
# 1396                       NaN                        Home WiFi
# 1397                       NaN                        Home WiFi
# 1398                       NaN                          Шо там?
# 1399                       NaN                             Home
# 1400                       NaN                          пацаєва
#
#                           address                  category         source  \
# 0                  Замковий узвіз  4bf58dd8d48988d163941735            NaN
# 1              бул. Шевченка, 197  4bf58dd8d48988d16d941735            NaN
# 2             вул. Смілянська, 31  4bf58dd8d48988d16e941735            NaN
# 3               вул. Різдв'яна 50  4bf58dd8d48988d1ca941735            NaN
# 4     вул. Героїв Сталінграда, 34  4bf58dd8d48988d1d2941735            NaN
# ...                           ...                       ...            ...
# 1396   Samiylo Kishka Street, 187  4e67e38e036454776db1fb3a  user_added_v3
# 1397       вулиця Івана Франка, 2  4e67e38e036454776db1fb3a  user_added_v3
# 1398        бульвар Шевченка, 224  5665c7b9498e7d8a4f2c0f06  user_added_v3
# 1399       вулиця Благовісна, 169  4e67e38e036454776db1fb3a  user_added_v3
# 1400           вулиця Пацаєва, 18  4d4b7105d754a06372d81259  user_added_v3
#
#              ssid              bssid                  deleted_at  \
# 0             NaN                NaN  2017-06-19 13:13:09.353331
# 1             NaN                NaN  2017-06-19 12:38:02.841161
# 2             NaN                NaN  2016-04-08 05:09:58.807097
# 3             NaN                NaN  2017-06-19 12:38:02.761925
# 4             NaN                NaN  2017-07-23 21:38:59.749558
# ...           ...                ...                         ...
# 1396  Xiaomi_3813  50:64:2b:64:38:14                         NaN
# 1397  Xiaomi_DABE  50:d2:f5:2d:da:bf                         NaN
# 1398   Sho_Tam_5G  dc:2c:6e:b8:5f:ed                         NaN
# 1399      blago26  84:16:f9:91:6a:52                         NaN
# 1400    ZTE Blade  b4:1c:30:d5:ad:e4                         NaN
#
#                       created_at                  updated_at  \
# 0     2012-09-21 08:15:03.000000  2017-06-19 13:13:09.000000
# 1     2013-05-12 23:40:22.000000  2017-06-19 12:38:02.000000
# 2     2013-05-12 23:40:22.000000  2016-04-08 05:09:58.000000
# 3     2013-07-07 04:40:37.000000  2017-06-19 12:38:02.000000
# 4     2013-07-07 04:40:37.000000  2017-07-23 21:39:00.000000
# ...                          ...                         ...
# 1396  2023-01-04 14:03:25.000000  2023-01-08 18:11:56.000000
# 1397  2023-01-14 12:27:56.000000  2023-01-15 07:43:12.000000
# 1398  2023-02-23 12:04:01.000000  2023-03-03 13:51:56.000000
# 1399  2023-03-08 22:06:54.000000  2023-03-11 16:17:06.000000
# 1400  2023-03-14 07:08:03.000000  2023-03-14 09:04:09.000000
#
#                           author_device_id       client_ip google_place_id  \
# 0                                      NaN             NaN             NaN
# 1                                      NaN             NaN             NaN
# 2                                      NaN             NaN             NaN
# 3                                      NaN             NaN             NaN
# 4                                      NaN             NaN             NaN
# ...                                    ...             ...             ...
# 1396  26995F9D-7CD1-4446-BB5E-7552D579E1D5  94.240.180.183             NaN
# 1397                      19a3a207d8c98806   91.244.31.132             NaN
# 1398                      43683f190401eedd   176.67.20.177             NaN
# 1399                      616edaa2924ed202   109.227.99.81             NaN
# 1400                      9e17a88fd71ced59  46.211.105.104             NaN
#
#      address_en           last_connected_at                last_seen_at  \
# 0           NaN                         NaN                         NaN
# 1           NaN                         NaN                         NaN
# 2           NaN                         NaN                         NaN
# 3           NaN                         NaN                         NaN
# 4           NaN                         NaN                         NaN
# ...         ...                         ...                         ...
# 1396        NaN  2023-01-04 14:04:12.172445  2023-01-08 18:00:00.000000
# 1397        NaN  2023-01-14 12:27:56.458808  2023-01-14 12:27:56.458808
# 1398        NaN  2023-02-23 12:04:27.188687  2023-02-23 12:04:01.955311
# 1399        NaN  2023-03-08 22:18:06.000000  2023-03-08 22:00:00.000000
# 1400        NaN  2023-03-14 09:04:09.000000  2023-03-14 07:08:03.301066
#
#                                       uuid  \
# 0     f30c0856-4d4d-4bab-a0f4-3ac073d3c01c
# 1     2a577b79-e05a-48bf-bd8a-7249ed66e4ea
# 2     bbd19c68-c1e3-466f-b8d1-fa74b5c6ae95
# 3     b4162c80-6592-432c-997d-3cdbf25dedbb
# 4     c6cf49e5-db39-4605-bcc8-68431d4093b2
# ...                                    ...
# 1396  4f34ea16-ef34-4bff-8c44-7d9ee4a6caf1
# 1397  df508e74-173e-4232-bf02-9a782030bdeb
# 1398  c3f144a8-ef56-4226-9c17-2c3890c882e3
# 1399  b2ea78b5-663d-4840-9b26-7d2805eb9751
# 1400  07f2dfc4-75d3-4dc5-8312-9d1f73df040d
#
#                                            service_info published_to_website  \
# 0     "photos"=>"[{\"id\":\"4f8c53aae4b0cec3adea06b2...                  NaN
# 1     "photos"=>"[{\"id\":\"50caeedee4b0212e79d792d3...                  NaN
# 2     "photos"=>"[{\"id\":\"51fe8bfd498e1e520a7b0091...                  NaN
# 3     "photos"=>"[{\"id\":\"4e5fa5fe52b171e17dbbc44e...                  NaN
# 4     "photos"=>"[{\"id\":\"5117a12ee4b0160c45ff88b2...                  NaN
# ...                                                 ...                  ...
# 1396                                                NaN                  NaN
# 1397                                      "wpa"=>"true"                  NaN
# 1398                                      "wpa"=>"true"                  NaN
# 1399                                      "wpa"=>"true"                  NaN
# 1400                                      "wpa"=>"true"                  NaN
#
#                                                  lonlat
# 0     0101000020E61000006FB9FAB149084040C0AE264F59B9...
# 1     0101000020E61000005C04C6FA06084040E17CEA58A5B8...
# 2     0101000020E610000031CEDF844208404057B439CE6DB8...
# 3     0101000020E61000005B28999CDA0B40409015FC36C4B6...
# 4     0101000020E61000008E3C1059A40B4040334FAE2990B7...
# ...                                                 ...
# 1396  0101000020E6100000D576137CD3064040A9143B1A87B4...
# 1397  0101000020E610000043AD69DE71064040C5C6BC8E38BA...
# 1398  0101000020E6100000F9DB9E20B107404052F01472A5B8...
# 1399  0101000020E610000054C72AA56706404080EECB99EDB8...
# 1400  0101000020E610000059F78F85E80C4040A7CAF78C44B4...
#
# [1400 rows x 20 columns]

# %%
category_columns = [
    "source",
    "category",
]

bool_columns = [
    "published_to_website",
]

date_columns = [
    "deleted_at",
    "created_at",
    "updated_at",
    "last_connected_at",
    "last_seen_at",

]
str_columns = [
    # "foursquare_id",
    "name",
    "address",
    "ssid",
    "bssid",
    "author_device_id",
    "client_ip",
    "address_en",
    # "google_place_id",
    "uuid",
    "service_info",
    # "category",
    "foursquare_id",
    "google_place_id",
]

# create the casting types dictionary
casting_types = {}
casting_types.update({col: "category" for col in category_columns})
casting_types.update({col: "bool" for col in bool_columns})
casting_types.update({col: "datetime64[ns]" for col in date_columns})
casting_types.update({col: "str" for col in str_columns})

hotspots = hotspots.astype(casting_types)

print(hotspots.select_dtypes(include='category').nunique())
print()
print(hotspots.select_dtypes(include='category'))
# Out:
# category    175
# source        2
# dtype: int64
#
#                       category         source
# 0     4bf58dd8d48988d163941735            NaN
# 1     4bf58dd8d48988d16d941735            NaN
# 2     4bf58dd8d48988d16e941735            NaN
# 3     4bf58dd8d48988d1ca941735            NaN
# 4     4bf58dd8d48988d1d2941735            NaN
# ...                        ...            ...
# 1396  4e67e38e036454776db1fb3a  user_added_v3
# 1397  4e67e38e036454776db1fb3a  user_added_v3
# 1398  5665c7b9498e7d8a4f2c0f06  user_added_v3
# 1399  4e67e38e036454776db1fb3a  user_added_v3
# 1400  4d4b7105d754a06372d81259  user_added_v3
#
# [1400 rows x 2 columns]

# %%
hotspots.select_dtypes(include='object').nunique()
# Out:
# foursquare_id        469
# name                 647
# address             1010
# ssid                1047
# bssid               1251
# author_device_id     916
# client_ip            947
# google_place_id      160
# address_en           216
# uuid                1400
# service_info         370
# lonlat              1325
# dtype: int64

# %%
## Delete foursquare_id and google_place_id
# NON_USEFUL_COLUMNS = ["foursquare_id", "google_place_id", "uuid", "service_info", "lonlat", "region_id"]

# categorish_columns = ["google_place_id", "client_ip", "author_device_id", "ssid"]
# "installation_id" - app id ?

# %% [markdown]
# ## Save

# %%
hotspots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1400 entries, 0 to 1400
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1400 non-null   int64
#  1   foursquare_id         1400 non-null   object
#  2   name                  1400 non-null   object
#  3   address               1400 non-null   object
#  4   lat                   1400 non-null   float64
#  5   lng                   1400 non-null   float64
#  6   category              1266 non-null   category
#  7   source                1221 non-null   category
#  8   ssid                  1400 non-null   object
#  9   bssid                 1400 non-null   object
#  10  altitude              1190 non-null   float64
#  11  deleted_at            479 non-null    datetime64[ns]
#  12  created_at            1400 non-null   datetime64[ns]
#  13  updated_at            1400 non-null   datetime64[ns]
#  14  source_id             14 non-null     float64
#  15  zone_id               1400 non-null   float64
#  16  owner_id              699 non-null    float64
#  17  author_device_id      1400 non-null   object
#  18  deleted_by            479 non-null    float64
#  19  client_ip             1400 non-null   object
#  20  google_place_id       1400 non-null   object
#  21  address_en            1400 non-null   object
#  22  last_connected_at     699 non-null    datetime64[ns]
#  23  download_speed        298 non-null    float64
#  24  upload_speed          298 non-null    float64
#  25  ping_time             294 non-null    float64
#  26  last_seen_at          981 non-null    datetime64[ns]
#  27  captive_portal_mode   857 non-null    float64
#  28  connections_count     1113 non-null   float64
#  29  uuid                  1400 non-null   object
#  30  service_info          1400 non-null   object
#  31  region_id             1327 non-null   float64
#  32  published_to_website  1400 non-null   bool
#  33  lonlat                1400 non-null   object
#  34  installation_id       186 non-null    float64
#  35  score_v3              1389 non-null   float64
#  36  score_v4              925 non-null    float64
# dtypes: bool(1), category(2), datetime64[ns](5), float64(16), int64(1), object(12)
# memory usage: 393.8+ KB

# %%
hotspots.to_parquet("cleaned_data/hotspots.parquet")

# %%
df = pd.read_parquet("cleaned_data/hotspots.parquet")
print(df.info())
del df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1400 entries, 0 to 1400
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1400 non-null   int64
#  1   foursquare_id         1400 non-null   object
#  2   name                  1400 non-null   object
#  3   address               1400 non-null   object
#  4   lat                   1400 non-null   float64
#  5   lng                   1400 non-null   float64
#  6   category              1266 non-null   category
#  7   source                1221 non-null   category
#  8   ssid                  1400 non-null   object
#  9   bssid                 1400 non-null   object
#  10  altitude              1190 non-null   float64
#  11  deleted_at            479 non-null    datetime64[ns]
#  12  created_at            1400 non-null   datetime64[ns]
#  13  updated_at            1400 non-null   datetime64[ns]
#  14  source_id             14 non-null     float64
#  15  zone_id               1400 non-null   float64
#  16  owner_id              699 non-null    float64
#  17  author_device_id      1400 non-null   object
#  18  deleted_by            479 non-null    float64
#  19  client_ip             1400 non-null   object
#  20  google_place_id       1400 non-null   object
#  21  address_en            1400 non-null   object
#  22  last_connected_at     699 non-null    datetime64[ns]
#  23  download_speed        298 non-null    float64
#  24  upload_speed          298 non-null    float64
#  25  ping_time             294 non-null    float64
#  26  last_seen_at          981 non-null    datetime64[ns]
#  27  captive_portal_mode   857 non-null    float64
#  28  connections_count     1113 non-null   float64
#  29  uuid                  1400 non-null   object
#  30  service_info          1400 non-null   object
#  31  region_id             1327 non-null   float64
#  32  published_to_website  1400 non-null   bool
#  33  lonlat                1400 non-null   object
#  34  installation_id       186 non-null    float64
#  35  score_v3              1389 non-null   float64
#  36  score_v4              925 non-null    float64
# dtypes: bool(1), category(2), datetime64[ns](5), float64(16), int64(1), object(12)
# memory usage: 393.8+ KB
# None
